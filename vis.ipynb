# %%
import pandas as pd

# %%
schedule = pd.read_csv('schedule.csv')

# %%
schedule

# %%
schedule['DDA'].unique()

# %%
CD = schedule[schedule['DDA'] == 'CD']
XA = schedule[schedule['DDA'] == 'XA']
ZZ = schedule[schedule['DDA'] == 'ZZ']

# %%
CD

# %%
for idx, row in CD.iterrows():
    print(row)
    break

# %%
for i in schedule['CODE'].unique():
    print(i,len(schedule[schedule['CODE'] == i]))

# %%
vehicle = pd.read_csv('vehicle.csv')

# %%
vehicle

# %%
import imageio
import matplotlib.pyplot as plt

# %%
im = imageio.imread('wagon.png')
print(im.shape)
# Out:
# (239, 851, 3)

# %%
b530 = imageio.imread('530.png')
b530 = b530[:,:,:3]
print(b530.shape)
# Out:
# (422, 640, 3)

# %%
plt.imshow(b530)

# %%
plt.imshow(im)

# %%
import cv2

# %%
res = cv2.resize(b530, dsize=(200, 100), interpolation=cv2.INTER_CUBIC)
plt.imshow(res)

# %%
wagon = im.copy()
wagon[0:100, 20:220, :] = res
wagon[0:100, 220:420, :] = res
plt.imshow(wagon)
